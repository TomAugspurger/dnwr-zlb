# %%
# %matplotlib inline
# %load_ext autoreload
# %connect_info
# Out:
# {
#   "stdin_port": 60202,
#   "ip": "127.0.0.1",
#   "control_port": 60203,
#   "hb_port": 60204,
#   "signature_scheme": "hmac-sha256",
#   "key": "fcdb4825-da1c-41f5-9ddf-1e230db5b0e8",
#   "shell_port": 60200,
#   "transport": "tcp",
#   "iopub_port": 60201
# }
#
# Paste the above JSON into a file, and connect with:
#     $> ipython <app> --existing <file>
# or, if you are local, you can connect with just:
#     $> ipython <app> --existing kernel-97359544-6dfa-4a33-af90-e65faa2ef193.json
# or even just:
#     $> ipython <app> --existing
# if this is the most recent IPython session you have started.

# %%
# %autoreload

import pandas as pd
import matplotlib.pyplot as plt
import prettyplotlib
import statsmodels.api as sm
import statsmodels.graphics as gr

from add_rec_bars import add_rec_bars
from helpers import add_demo_dummies, construct_wage_index, replace_categorical

# %%
# with pd.get_store('/Volumes/HDD/Users/tom/DataStorage/CPS/analyzed/clean.h5') as store:
#     df = store.select('cleaned')

# df.info()

with pd.get_store('/Volumes/HDD/Users/tom/DataStorage/CPS/analyzed/clean.h5') as store:
    trim = store.select('trim')

with pd.get_store('/Volumes/HDD/Users/tom/DataStorage/CPS/analyzed/analyzed_store.h5') as store:
    prod = store.select('major_sectors_output_per_hour')

trim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1617075 entries, (1996-01-01 00:00:00, 17602036881.0, 65001, 1.0) to (2013-04-01 00:00:00, 9.99800062281e+14, 90001, 2.0)
# Data columns (total 34 columns):
# edu                    1617075  non-null values
# age                    1617075  non-null values
# month_in_sample        1617075  non-null values
# flow                   1617075  non-null values
# same_employer          1560660  non-null values
# nonemployed_history    1617075  non-null values
# year                   1617075  non-null values
# either_history         1617075  non-null values
# industry               1617075  non-null values
# hours                  1617075  non-null values
# og_weight              1617075  non-null values
# earnings               1617075  non-null values
# labor_status           1617075  non-null values
# unemployed_history     1617075  non-null values
# month                  1617075  non-null values
# ...

# %%
# df.head()
# Out:
#                                                        stamp  edu  age  \
# qmonth     HRHHID       HRHHID2 PULINENO
# 1996-01-01 1.760204e+10 65001   1        1996-01-01 00:00:00   42   43
#                                 2        1996-01-01 00:00:00   43   47
#            1.670991e+11 65001   1        1996-01-01 00:00:00   43   57
#            2.670991e+11 65001   1        1996-01-01 00:00:00   32   36
#            4.670991e+11 65001   1        1996-01-01 00:00:00   43   35
#
#                                           month_in_sample  flow  \
# qmonth     HRHHID       HRHHID2 PULINENO
# 1996-01-01 1.760204e+10 65001   1                       4     1
#                                 2                       4     1
#            1.670991e+11 65001   1                       4     1
#            2.670991e+11 65001   1                       4     7
#            4.670991e+11 65001   1                       4     1
#
# ...

# %%
# Setup
df['either_history'] = df.either_history.replace(-1, np.nan)

s_dummies = pd.get_dummies(df.quarter).rename(columns={1: "Q1", 2: "Q2",
                                                       3: "Q3", 4: "Q4"})
df = pd.concat([df, s_dummies], axis=1)

# Add time trend
df['trend'] = df.year - 1996 + df.quarter

# Filter out outer .005% of hours and .003% of real hourly earnings
low_hours, high_hours = df.hours.quantile(.005), df.hours.quantile(.995)
low_earn, high_earn = df.real_hr_earns.quantile(.003), df.real_hr_earns.quantile(.997)

trim = df.query('hours > low_hours & hours < high_hours &'
                'real_hr_earns > low_earn & real_hr_earns < high_earn')

# Deseasonalize real hourly wages

seasonal_mod = sm.OLS.from_formula("np.log(real_hr_earns) ~ Q1 + Q2 + Q3", trim)
seasonal_res = seasonal_mod.fit()

seasonal_effects = seasonal_res.params
seasonal_effects['Q4'] = 0

# BUG https://github.com/pydata/pandas/issues/5653
# real_hr_earns_d = df.set_index('quarter', append=True)['real_hr_earns'].copy()
# real_hr_earns_d = real_hr_earns_d.rename(index={1: "Q1", 2: "Q2", 3: "Q3",
#                                                 4: "Q4"}, level='quarter')

real_hr_earns_d = trim[['quarter', 'real_hr_earns']].copy()
real_hr_earns_d['quarter'] = real_hr_earns_d['quarter'].replace({1: "Q1", 2: "Q2",
                                                                 3: "Q3", 4: "Q4"})
real_hr_earns_d = real_hr_earns_d.set_index('quarter', append=True)
# Series for sub
real_hr_earns_d = np.log(real_hr_earns_d['real_hr_earns']).sub(seasonal_effects,
                                                               level='quarter')
idx = real_hr_earns_d.index.droplevel('quarter')  # to match with trim
real_hr_earns_d.index = idx
trim['ln_real_hr_earns_d'] = real_hr_earns_d

# First Stage

trim = add_demo_dummies(trim)
trim['expr_2'] = trim.expr ** 2
trim['expr_3'] = trim.expr ** 3
trim['expr_4'] = trim.expr ** 4

# %%
k = sm.nonparametric.KDEUnivariate(real_hr_earns_d)
k.fit()

fig, ax = plt.subplots(figsize=(13, 8))
ax.plot(k.support, k.density)

# %% [markdown]
# ### First Stage:
#
# \begin{equation}
#     \ln w_{it} = \boldsymbol{x_{i}}^T \boldsymbol{\beta} + \ln \hat{w}_{it}
# \end{equation}
#
# Regressing each individual $i$'s wage at time $t$ on demographic variables:
#
# - `age`
# - `sex_d`: (female=1)
# - `race_d`: (black=1)
# - `married_d`: (with spouse present=1)
# - `edu_bin`:
#         0. Didn't finish highschool
#         1. Highschool or GED
#         2. Some college
#         3. Associate
#         4. Finished college
#         5. Some graduate
# - $expr + expr^2 + expr^3 + expr^4$ experience
# - `Q1 .. Q3`: quarterly dummies

# %%
mod_fs = sm.OLS.from_formula("ln_real_hr_earns_d ~ age + sex_d + race_d +"
                             "married_d + edu_bin + expr + expr_2 +"
                             "expr_3 + expr_4 + trend", trim)
res_fs = mod_fs.fit()
res_fs.summary2()

trim['resid_fs'] = res_fs.resid

# %%
k = sm.nonparametric.KDEUnivariate(res_fs.resid)
k.fit()

fig, ax = plt.subplots(figsize=(13, 8))
ax.plot(k.support, k.density)

# %%
fig, ax = plt.subplots(figsize=(13, 8))
ax.scatter(trim.ln_real_hr_earns_d.values, res_fs.resid.values, color='k', marker='.', alpha=.1)

# %%
trim['either_history'] = trim.either_history.replace(-1, np.nan)

# %%
mod_fs = sm.OLS.from_formula("ln_real_hr_earns_d ~ age + sex_d + race_d +"
                             "married_d + edu_bin + expr + expr_2 +"
                             "expr_3 + expr_4 + trend", trim.dropna(subset=['either_history']))
res_fs = mod_fs.fit()
res_fs.summary2()

trim['resid_fs'] = res_fs.resid

# %%
fig, ax = plt.subplots(figsize=(13, 8))
ax.scatter(trim.dropna().ln_real_hr_earns_d.values, res_fs.resid.values, color='k', marker='.', alpha=.1)

# %%
trim.loc[:, 'real_hr_earns_d'] = real_hr_earns_d
fig, ax = plt.subplots(figsize=(13, 8))
ax.scatter(trim.dropna().real_hr_earns_d.values, res_fs.resid.values, color='k', marker='.', alpha=.1)

# %% [markdown]
# ### Second Stage
#
# \begin{equation}
#     \Delta \ln \hat{w}_{jt} = \alpha_j + \eta_j \Delta \ln y_{jt} + \epsilon_{jt}
# \end{equation}
#
# So we are interested in $\eta_j$ the elasticity of the wage with respect to productivity (we're in log differences here).
#
# The $\hat{w}_{jt}$ are the residuals from the first stage, grouped by time and subgroup (existing employed vs. hired from nonemployment). They are aggregated by mean or median.

# %%
g = trim.reset_index().groupby(['qmonth', 'either_history'])['resid_fs']
mean_resid_fs = g.agg('mean').unstack(['either_history'])[[0, 1]]

prod = trim[['productivity']].groupby(level='qmonth').mean()
prod.name = 'productivity'

mean_resid_fs = pd.concat([mean_resid_fs, prod], axis=1)
first_diff = mean_resid_fs.diff().dropna()
first_diff = first_diff.rename(columns={0: 'from_e', 1: 'from_n'})

# %%
mod_e_ss = sm.OLS.from_formula("np.log(from_e) ~ np.log(productivity)", first_diff)
res_e_ss = mod_e_ss.fit()
res_e_ss.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         np.log(from_e)   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.034
# Method:                 Least Squares   F-statistic:                  0.001713
# Date:                Tue, 10 Dec 2013   Prob (F-statistic):              0.967
# Time:                        15:07:18   Log-Likelihood:                -45.895
# No. Observations:                  31   AIC:                             95.79
# Df Residuals:                      29   BIC:                             98.66
# Df Model:                           1
# ...
#                            coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------
# Intercept               -5.1150      0.234    -21.891      0.000        -5.593    -4.637
# ...

# %%
mod_n_ss = sm.OLS.from_formula("np.log(from_n) ~ np.log(productivity)", first_diff)
res_n_ss = mod_n_ss.fit()
res_n_ss.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         np.log(from_n)   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.040
# Method:                 Least Squares   F-statistic:                  0.002222
# Date:                Tue, 10 Dec 2013   Prob (F-statistic):              0.963
# Time:                        15:07:31   Log-Likelihood:                -41.628
# No. Observations:                  27   AIC:                             87.26
# Df Residuals:                      25   BIC:                             89.85
# Df Model:                           1
# ...
#                            coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------
# Intercept               -4.2920      0.257    -16.704      0.000        -4.821    -3.763
# ...

# %% [markdown]
# # Via Estimating 2

# %% [markdown]
# Above, I estimated the elasticity wrt productivity from using the regressions in the first statge.
#
# Now I'm going to use equation 2:
#
# \begin{equation}
#     \ln \hat{w}_{jt} = \ln w_{jt} - \boldsymbol{(x_{jt} - \bar{x}_{j})^T \beta}
# \end{equation}
#
# The first part generates the wage index. Break into subgroups $j$ according to history.

# %%
g_ts = trim.reset_index().groupby(['qmonth', 'either_history'])
mean_ts = g_ts[res_fs.params.index[1:]].mean()
means = trim.groupby('either_history')[res_fs.params.index[1:]].mean()

deviations = mean_ts.sub(means, level='either_history')

mean_earn = g_ts['ln_real_hr_earns_d'].mean()

# %%
# employed first
w_et = mean_earn.ix[: 0]
dev_e = deviations.xs(0, level='either_history')

r_e = dev_e.dot(res_fs.params.iloc[1:])

# %%
# now unemployed
w_nt = mean_earn.ix[:, 1]
dev_n = deviations.xs(1, level='either_history')

r_n = dev_n.dot(res_fs.params.iloc[1:])

# %%
r_e.plot(label='e')
r_n.plot(label='n')
plt.legend()

# %%
ax = np.log(trim.real_hr_earns).groupby(level='qmonth').mean().plot(label='NSA')
ax = trim.ln_real_hr_earns_d.groupby(level='qmonth').mean().plot(label='SA', ax=ax)
ax.legend()

# %%
with pd.get_store('/Volumes/HDD/Users/tom/DataStorage/CPS/analyzed/analyzed_store.h5') as store:
    prod = store.select('major_sectors_output_per_hour')
    u_rate = store.select('u_rate')

# %%
print(prod.head())
print(trim.productivity.head())
# Out:
# series_id   durable  nondurable  business
# stamp
# 1996-01-01   60.236      69.035    70.842
# 1996-04-01   60.835      68.991    71.688
# 1996-07-01   61.946      69.384    71.991
# 1996-10-01   62.326      69.991    71.998
# 1997-01-01   63.211      71.076    71.804
#
# [5 rows x 3 columns]
# qmonth      HRHHID        HRHHID2  PULINENO
# 1996-01-01  1.760204e+10  65001    1           70.842
#                                    2           70.842
#             1.670991e+11  65001    1           70.842
#             2.670991e+11  65001    1           70.842
#             4.670991e+11  65001    1           70.842
# Name: productivity, dtype: float64

# %%
df_ss.head()
# Out:
#               from_e  productivity
# 1996-01-01 -0.166996        70.842
# 1996-04-01 -0.167286        71.688
# 1996-07-01 -0.167708        71.991
# 1996-10-01 -0.156922        71.998
# 1997-01-01 -0.143244        71.804
#
# [5 rows x 2 columns]

# %%
df_ss = pd.concat([r_e, np.log(prod.business)], axis=1, keys=['from_e', 'productivity'])
mod_ss = sm.OLS.from_formula('from_e ~ productivity', df_ss.diff().dropna())
res_ss = mod_ss.fit()
res_ss.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 from_e   R-squared:                       0.041
# Model:                            OLS   Adj. R-squared:                  0.027
# Method:                 Least Squares   F-statistic:                     2.866
# Date:                Tue, 10 Dec 2013   Prob (F-statistic):             0.0951
# Time:                        15:59:03   Log-Likelihood:                 283.98
# No. Observations:                  69   AIC:                            -564.0
# Df Residuals:                      67   BIC:                            -559.5
# Df Model:                           1
# ...
#                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# Intercept        0.0056      0.001      8.905      0.000         0.004     0.007
# ...

# %%
mod_ss = sm.OLS.from_formula('from_e ~ productivity', df_ss)
res_ss = mod_ss.fit()
res_ss.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 from_e   R-squared:                       0.975
# Model:                            OLS   Adj. R-squared:                  0.975
# Method:                 Least Squares   F-statistic:                     2661.
# Date:                Tue, 10 Dec 2013   Prob (F-statistic):           2.95e-56
# Time:                        16:00:14   Log-Likelihood:                 194.81
# No. Observations:                  70   AIC:                            -385.6
# Df Residuals:                      68   BIC:                            -381.1
# Df Model:                           1
# ...
#                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# Intercept       -3.3433      0.065    -51.609      0.000        -3.473    -3.214
# ...

# %%
df_ss = pd.concat([r_n, np.log(prod.business)], axis=1, keys=['from_n', 'productivity'])
mod_ss = sm.OLS.from_formula('from_n ~ productivity', df_ss.diff().dropna())
res_ss = mod_ss.fit()
res_ss.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 from_n   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                 -0.007
# Method:                 Least Squares   F-statistic:                    0.5537
# Date:                Tue, 10 Dec 2013   Prob (F-statistic):              0.459
# Time:                        16:00:47   Log-Likelihood:                 173.10
# No. Observations:                  69   AIC:                            -342.2
# Df Residuals:                      67   BIC:                            -337.7
# Df Model:                           1
# ...
#                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# Intercept        0.0067      0.003      2.150      0.035         0.000     0.013
# ...

# %%
df_ss = pd.concat([r_n, np.log(prod.business)], axis=1, keys=['from_n', 'productivity'])
mod_ss = sm.OLS.from_formula('from_n ~ productivity', df_ss)
res_ss = mod_ss.fit()
res_ss.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 from_n   R-squared:                       0.962
# Model:                            OLS   Adj. R-squared:                  0.961
# Method:                 Least Squares   F-statistic:                     1707.
# Date:                Tue, 10 Dec 2013   Prob (F-statistic):           6.71e-50
# Time:                        16:00:56   Log-Likelihood:                 178.43
# No. Observations:                  70   AIC:                            -352.9
# Df Residuals:                      68   BIC:                            -348.4
# Df Model:                           1
# ...
#                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# Intercept       -3.3863      0.082    -41.363      0.000        -3.550    -3.223
# ...

# %% [markdown]
# # With unemployment rate

# %%
df_ss = pd.concat([r_e, np.log(u_rate.u_rate.resample('QS'))], axis=1, keys=['from_e', 'u_rate'])
mod_ss = sm.OLS.from_formula('from_e ~ u_rate', df_ss.diff().dropna())
res_ss = mod_ss.fit()
res_ss.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 from_e   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                 -0.008
# Method:                 Least Squares   F-statistic:                    0.4935
# Date:                Tue, 10 Dec 2013   Prob (F-statistic):              0.485
# Time:                        15:44:39   Log-Likelihood:                 282.79
# No. Observations:                  69   AIC:                            -561.6
# Df Residuals:                      67   BIC:                            -557.1
# Df Model:                           1
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      0.0049      0.000      9.902      0.000         0.004     0.006
# ...

# %%
df_ss = pd.concat([r_n, np.log(u_rate.u_rate.resample('QS'))], axis=1, keys=['from_n', 'u_rate'])
mod_ss = sm.OLS.from_formula('from_n ~ u_rate', df_ss.diff().dropna())
res_ss = mod_ss.fit()
res_ss.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 from_n   R-squared:                       0.020
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     1.376
# Date:                Tue, 10 Dec 2013   Prob (F-statistic):              0.245
# Time:                        15:43:52   Log-Likelihood:                 173.52
# No. Observations:                  69   AIC:                            -343.0
# Df Residuals:                      67   BIC:                            -338.6
# Df Model:                           1
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      0.0050      0.002      2.074      0.042         0.000     0.010
# ...

# %% [markdown]
# # Some graphs

# %%
# mean resid by quarter, group
g = trim.reset_index().groupby(['qmonth', 'either_history'])
earn_mean_ts = g['resid_fs'].agg('mean').unstack('either_history')[[0, 1]]
fig, ax = plt.subplots(figsize=(13,8))
ax = earn_mean_ts.plot(ax=ax)
add_rec_bars(ax)

# %%
# sex
sex_ts = g['sex_d'].agg('mean').unstack('either_history')[[0, 1]]
sex_ts.plot(title='sex')

# race
plt.figure()
race_ts = g['race_d'].agg('mean').unstack('either_history')[[0, 1]]
race_ts.plot(title='race')

# age
age_ts = g['age'].agg('mean').unstack('either_history')[[0, 1]]
age_ts.plot(title='age')

# edu
edu_ts = g['edu_bin'].agg('mean').unstack('either_history')[[0, 1]]
edu_ts.plot(title='edu')

# married
plt.figure()
married_ts = g['married_d'].agg('mean').unstack('either_history')[[0, 1]]
married_ts.plot(title='married')

# expr
plt.figure()
expr_ts = g['expr'].agg('mean').unstack('either_history')[[0, 1]]
expr_ts.plot(title='experience')

# %% [markdown]
# ## Demographics-Deviation from sample means

# %%
r = trim.groupby(['either_history'])[['sex_d', 'race_d', 'edu_bin', 'age',
                                      'married_d', 'expr']].agg(['mean', 'count'])
means = r.xs('mean', axis=1, level=1).T[[0, 1]]
means
# Out:
# either_history          0          1
# sex_d            0.494058   0.529927
# race_d           0.085021   0.127911
# edu_bin          2.478284   1.954919
# age             42.822039  41.534879
# married_d        0.692371   0.599834
# expr            22.093920  21.962482
#
# [6 rows x 2 columns]

# %%
fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6)) = plt.subplots(figsize=(18, 10), nrows=3, ncols=2)

age_ts.sub(means.ix['age']).plot(ax=ax1, title='age')
sex_ts.sub(means.ix['sex_d']).plot(ax=ax2, title='sex')
expr_ts.sub(means.ix['expr']).plot(ax=ax3, title='expr')
edu_ts.sub(means.ix['edu_bin']).plot(ax=ax4, title='edu')
race_ts.sub(means.ix['race_d']).plot(ax=ax5, title='sex')
married_ts.sub(means.ix['married_d']).plot(ax=ax6, title='married')

axes = [ax1, ax2, ax3, ax4, ax5, ax6]
[add_rec_bars(ax) for ax in axes]
[ax.hlines(0, age_ts.index[0], age_ts.index[-1]) for ax in axes]

fig.tight_layout()

# %% [markdown]
# Estimating (2): $ \ln \hat{w}_{jt} = \ln w_{jt} - (x_{jt} - \bar{x}_j)^T \boldsymbol{\beta}$
#
# where $x_{jt}$ is the average observables for subgroup $j$ at $t$ and the $\bar{x}_j$ is for that group over the sample period.

# %%
demo_means_ts = pd.concat([sex_ts, race_ts, age_ts, edu_ts, married_ts, expr_ts], axis=1,
                          keys=['age', 'sex_d', 'race_d', 'married_d', 'edu_bin', 'expr'])
demo_means_ts.head()
# Out:
#                      age               sex_d               race_d             \
# either_history         0         1         0         1          0          1
# qmonth
# 1996-01-01      0.492012  0.531191  0.089000  0.130435  40.544458  38.688091
# 1996-04-01      0.487650  0.485390  0.084568  0.128247  40.441179  39.551948
# 1996-07-01      0.477096  0.568404  0.089158  0.148208  40.616078  39.403909
# 1996-10-01      0.491670  0.610900  0.090755  0.131812  40.722911  39.641318
# 1997-01-01      0.495894  0.542611  0.084787  0.105717  41.348204  40.486516
#
#                 married_d             edu_bin                 expr
# either_history          0         1         0         1          0          1
# qmonth
# 1996-01-01       2.311251  1.742911  0.698787  0.621928  20.128398  19.536862
# 1996-04-01       2.287616  1.706169  0.694047  0.618506  20.068325  20.400974
# 1996-07-01       2.242645  1.863192  0.693518  0.573290  20.345653  20.035831
# ...

# %%
means
# Out:
# either_history          0          1
# sex_d            0.493623   0.532137
# race_d           0.084906   0.125757
# edu_bin          2.468123   1.942961
# age             42.773031  41.600071
# married_d        0.694181   0.601908
# expr            22.061831  22.051157
#
# [6 rows x 2 columns]

# %%
d0 = demo_means_ts.xs(0, axis=1, level=1).sub(means[0])
d1 = demo_means_ts.xs(1, axis=1, level=1).sub(means[1])

# %%
res.params
# Out:
# Intercept    6.121114
# age          0.052436
# sex_d       -0.249390
# race_d      -0.093416
# married_d    0.071266
# edu_bin      0.069161
# expr        -0.045898
# dtype: float64

# %%
d0['Intercept'] = 1
d0.dot(res.params).plot()
plt.figure()
d1['Intercept'] = 1
d1.dot(res.params).plot()

# %%
# mean resid by quarter, group
g = df.reset_index().groupby(['qmonth', 'either_history'])
earn_mean_ts = g['wage_index_res'].agg('mean').unstack('either_history')[[0, 1]]
fig, ax = plt.subplots(figsize=(13,8))
ax = earn_mean_ts.plot(ax=ax)
add_rec_bars(ax)

# %%
fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6)) = plt.subplots(figsize=(13, 10), nrows=3, ncols=2)

# sex
sex_ts = g['sex_d'].agg('mean').unstack('either_history')[[0, 1]]
sex_ts.plot(title='sex', ax=ax1)

# race
plt.figure()
race_ts = g['race_d'].agg('mean').unstack('either_history')[[0, 1]]
race_ts.plot(title='race', ax=ax2)

# age
age_ts = g['age'].agg('mean').unstack('either_history')[[0, 1]]
age_ts.plot(title='age', ax=ax3)

# edu
edu_ts = g['edu_bin'].agg('mean').unstack('either_history')[[0, 1]]
edu_ts.plot(title='edu', ax=ax4)

# married
plt.figure()
married_ts = g['married_d'].agg('mean').unstack('either_history')[[0, 1]]
married_ts.plot(title='married', ax=ax5)

# expr
plt.figure()
expr_ts = g['expr'].agg('mean').unstack('either_history')[[0, 1]]
expr_ts.plot(title='experience', ax=ax6)

# %%
df['resid'] = res.resid

# %%
cols = ['sex_d', 'race_d', 'age', 'edu_bin', 'married_d', 'expr', 'resid', 'productivity']
g = df.reset_index().groupby(['qmonth', 'either_history'])
together = g.agg({k: np.mean for k in cols})

diff_0 = together.xs(0, level='either_history')
diff_1 = together.xs(1, level='either_history')

# %%
mod = sm.OLS.from_formula("resid ~ expr + age + married_d + race_d + sex_d + productivity", diff_0.diff().dropna())
res = mod.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  resid   R-squared:                       0.119
# Model:                            OLS   Adj. R-squared:                  0.025
# Method:                 Least Squares   F-statistic:                     1.266
# Date:                Thu, 05 Dec 2013   Prob (F-statistic):              0.288
# Time:                        22:54:46   Log-Likelihood:                 139.10
# No. Observations:                  63   AIC:                            -264.2
# Df Residuals:                      56   BIC:                            -249.2
# Df Model:                           6
# ...
#                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# Intercept        0.0038      0.006      0.683      0.497        -0.007     0.015
# ...

# %%
mod = sm.OLS.from_formula("resid ~ expr + age + married_d + race_d + sex_d + productivity", diff_1.diff().dropna())
res = mod.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  resid   R-squared:                       0.083
# Model:                            OLS   Adj. R-squared:                 -0.015
# Method:                 Least Squares   F-statistic:                    0.8468
# Date:                Thu, 05 Dec 2013   Prob (F-statistic):              0.539
# Time:                        22:55:56   Log-Likelihood:                 127.90
# No. Observations:                  63   AIC:                            -241.8
# Df Residuals:                      56   BIC:                            -226.8
# Df Model:                           6
# ...
#                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# Intercept        0.0080      0.006      1.356      0.181        -0.004     0.020
# ...

# %% [markdown]
# # Earnings Plots

# %%
aggfuncs = ['mean', 'median', 'std', 'count']

# %%
by_sex = df.groupby('sex')['real_hr_earns'].agg(aggfuncs)
by_sex = replace_categorical(by_sex, kind='sex', index=True)
by_sex
# Out:
#                mean       median          std   count
# sex
# male    2268.980388  1911.010998  2195.469204  775660
# female  1799.213010  1473.926956  1850.430313  760872
#
# [2 rows x 4 columns]

# %%
by_race = df.groupby('race')['earnings'].agg(aggfuncs)
by_race = replace_categorical(by_race, kind='race', index=True)
by_race.sort(columns='mean', ascending=False, inplace=True)
by_race
# Out:
#                                                mean   median           std  \
# race
# W-B-A                                 104785.363636  87025.0  71702.184330
# White-Asian                            95134.767564  80000.0  62790.523902
# Black-Asian                            86394.357798  76923.0  49478.112196
# Asian Only                             85946.124260  69200.0  60974.349538
# W-A-HP                                 83859.313253  68000.0  61424.653056
# W-B-AI                                 83557.346939  81400.0  43765.836656
# AI-Asian                               80776.086957  57692.0  56440.963477
# White Only                             79297.705211  65384.0  55111.710616
# White-HP                               78210.717033  67307.0  51134.794754
# White-Black                            77750.738260  64000.0  54378.005774
# Black-AI                               77739.104361  60800.0  52896.113582
# ...

# %%
# plot just one and color by count
fig, ax = plt.subplots(figsize=(13,8))
by_race[['mean', 'median']].plot(kind='barh', ax=ax)

# %%
by_age = df.groupby('age')['real_hr_earns'].agg(aggfuncs)
by_age
# Out:
#             mean       median          std  count
# age
# 24   1204.291314  1020.686466   678.608808      6
# 25   1496.885400  1272.278120  1800.714122  21627
# 26   1548.962031  1332.019492  1409.555966  33563
# 27   1598.033483  1385.427535   956.378100  34618
# 28   1674.883976  1430.816138  2127.322954  36067
# 29   1720.720473  1482.638305  1278.365444  37360
# 30   1762.090608  1505.120866  1209.250676  39187
# 31   1806.268218  1537.137236  1310.937533  39754
# 32   1868.797774  1573.339798  1498.104489  40333
# 33   1893.119918  1580.945956  1760.384134  41321
# 34   1922.146828  1598.808951  1768.850849  42569
# 35   2015.786640  1685.574188  1475.795944  44203
# 36   2040.177607  1698.912696  1842.759721  44990
# 37   2055.108156  1696.279159  2092.235692  45985
# 38   2072.083710  1703.910478  2389.425360  47252
# 39   2059.871154  1707.662374  1947.514142  48426
# 40   2077.177109  1720.130146  1921.850234  50513
# 41   2095.748902  1730.409267  1874.804310  51306
# ...

# %%
fig, ax = plt.subplots(figsize=(13,8))
ax = by_age['mean'].plot(kind='bar', ax=ax, rot=45)

# %%
by_edu = df.groupby('edu')['real_hr_earns'].agg(aggfuncs)
by_edu
# Out:
#             mean       median          std   count
# edu
# 31   1000.944377   853.006977  1150.363765    2119
# 32   1064.679508   922.282341   718.753230    6091
# 33   1095.812009   947.369903   876.592915   14610
# 34   1168.985725  1006.137438   849.871204   14621
# 35   1177.086040  1013.089111   735.253400   16370
# 36   1250.808163  1065.330284  1326.456420   21347
# 37   1279.706867  1082.859157  1072.977054   25795
# 38   1348.893490  1135.404437  1068.779623   13224
# 39   1603.953252  1387.631976  1547.252335  462955
# 40   1804.826160  1543.947725  1744.686914  277700
# 41   1888.328851  1684.819774  1345.718395   86957
# 42   1984.643027  1738.122827  1725.122718   81236
# 43   2573.926018  2212.636919  2347.979608  336437
# 44   2996.685304  2633.900112  3024.390658  131942
# 45   3573.680182  3227.336896  3337.629688   23474
# 46   3508.610892  3201.802308  2457.720852   21654
#
# [16 rows x 4 columns]

# %%
by_edu['mean'].plot(kind='bar')

# %%
pd.value_counts(df.flow)
# Out:
# 1    1517301
# 7      13821
# 4       5410
# dtype: int64

# %%
by_flow = df.groupby('flow')['real_hr_earns'].agg(aggfuncs)
by_flow = replace_categorical(by_flow, kind='flow', index=True)
by_flow
# Out:
#              mean       median          std    count
# flow
# ee    2040.491601  1686.469557  2034.598531  1517301
# ue    1830.482814  1390.745783  2368.823170     5410
# ne    1663.068462  1142.743578  2887.965732    13821
#
# [3 rows x 4 columns]

# %%
df.columns
# Out:
# Index([u'stamp', u'edu', u'age', u'month_in_sample', u'flow', u'same_employer', u'nonemployed_history', u'year', u'either_history', u'race', u'married', u'industry', u'hours', u'earnings', u'labor_status', u'unemployed_history', u'sex', u'month', u'expr', u'real_hr_earns', u'quarter', u'productivity', u'D_0', u'D_1', u'D_2'], dtype='object')

# %%
by_history_u = df.groupby('unemployed_history')['earnings'].agg(aggfuncs)
by_history_u
# Out:
#                             mean  median           std    count
# unemployed_history
# -1                  67496.822380   53846  53675.968462    64396
#  0                  79151.659196   65051  54584.295680  1429264
#  1                  53541.784125   40000  43497.200182    42872
#
# [3 rows x 4 columns]

# %%
by_history_n = df.groupby('nonemployed_history')['earnings'].agg(aggfuncs)
by_history_n
# Out:
#                              mean  median           std    count
# nonemployed_history
# -1                   67948.839559   54000  51740.869278    74158
#  0                   79151.659196   65051  54584.295680  1429264
#  1                   48414.941075   36000  44100.499713    33110
#
# [3 rows x 4 columns]

# %%
by_history_e = df.groupby('either_history')['earnings'].agg(aggfuncs)
by_history_e
# Out:
#                         mean  median           std    count
# either_history
# -1              80633.663806   66000  55681.315915    37053
#  0              79151.659196   65051  54584.295680  1429264
#  1              52043.717126   40000  44164.434934    70215
#
# [3 rows x 4 columns]

# %% [markdown]
# # Time Series

# %%
by_month = df.groupby(level='qmonth')['real_hr_earns'].agg(aggfuncs)

# %%
by_month.head()
# Out:
#                    mean       median          std  count
# qmonth
# 1996-01-01  1735.999039  1463.396788  1759.757689  12037
# 1996-04-01  1717.898571  1460.227065  1361.471556  11907
# 1996-07-01  1709.945643  1456.381378  1604.712767  11871
# 1996-10-01  1749.208794  1463.732463  1709.335635  16244
# 1997-01-01  1788.514289  1516.456587  1332.570843  22800
#
# [5 rows x 4 columns]

# %%
by_month.head()
# Out:
#                   mean       median          std  count
# qmonth
# 1996-01-01  747.233604  1407.086499  5068.860341  12461
# 1996-04-01  731.886583  1404.038745  5066.430463  12503
# 1996-07-01  518.963896  1400.341036  5643.404492  12816
# 1996-10-01  640.897553  1415.604239  5484.640831  16751
# 1997-01-01  854.493551  1458.103337  5090.109457  23442
#
# [5 rows x 4 columns]

# %%
# Out:
# qmonth
# 1996-01-01    6475.946840
# 1996-04-01    6470.469207
# 1996-07-01    7043.745528
# 1996-10-01    6900.245069
# 1997-01-01    6548.212794
# dtype: float64

# %%
fig, ax = plt.subplots(figsize=(13,8))
ax = by_month['median'].plot(ax=ax)
upper = by_month['median'] + by_month['std']
lower = by_month['median'] - by_month['std']
ax.fill_between(by_month.index, lower, upper, alpha=.3)

# %%
by_month['mean'].plot()

# %%
# need a hist/kde plot of earnings

# %% [markdown]
# # Wage Index

# %%
df.columns
# Out:
# Index([u'stamp', u'edu', u'age', u'month_in_sample', u'flow', u'same_employer', u'nonemployed_history', u'year', u'either_history', u'race', u'married', u'industry', u'hours', u'earnings', u'labor_status', u'unemployed_history', u'sex', u'month', u'expr', u'real_hr_earns', u'productivity', u'quarter', u'D_0', u'D_1', u'D_2', u'D_0', u'D_1', u'D_2'], dtype='object')

# %%
# Get Series for observable characteristics of each subgroup
res = df.reset_index()
g = res.groupby(['qmonth', 'either_history'])
char = res.groupby(['qmonth', 'either_history'])

# %%
r = g[['edu', 'age', 'race', 'married', 'expr']].agg('mean')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-93-38b24cf303bb> in <module>()
# ----> 1 r = g[['edu', 'age', 'race', 'married', 'expr']].agg('mean')
#
# /Users/tom/Envs/pandas-dev/lib/python2.7/site-packages/pandas-0.13.0rc1-py2.7-macosx-10.8-x86_64.egg/pandas/core/groupby.pyc in agg(self, func, *args, **kwargs)
#     402     @Appender(_agg_doc)
#     403     def agg(self, func, *args, **kwargs):
# --> 404         return self.aggregate(func, *args, **kwargs)
#     405
#     406     def _iterate_slices(self):
#
# /Users/tom/Envs/pandas-dev/lib/python2.7/site-packages/pandas-0.13.0rc1-py2.7-macosx-10.8-x86_64.egg/pandas/core/groupby.pyc in aggregate(self, arg, *args, **kwargs)
#    1949     def aggregate(self, arg, *args, **kwargs):
#    1950         if isinstance(arg, compat.string_types):
# -> 1951             return getattr(self, arg)(*args, **kwargs)
# ...

# %%
# Regresssion
# TOOD: fixup married
import statsmodels.api as sm

# %%
model = sm.OLS.from_formula("real_hr_earns ~ age + sex + race + married + productivity", df)


# with seasonal
model = sm.OLS.from_formula("np.log(real_hr_earns) ~ age + sex + race + married + productivity "
                            "+  D_0 + D_1 + D_2", df[df.real_hr_earns > 0])
res = model.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ...
# Dep. Variable:     np.log(real_hr_earns)   R-squared:                       0.076
# Model:                               OLS   Adj. R-squared:                  0.076
# Method:                    Least Squares   F-statistic:                 1.438e+04
# Date:                   Tue, 03 Dec 2013   Prob (F-statistic):               0.00
# Time:                           19:31:04   Log-Likelihood:            -1.2363e+06
# No. Observations:                1406451   AIC:                         2.473e+06
# Df Residuals:                    1406442   BIC:                         2.473e+06
# Df Model:                              8
# ...
#                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# Intercept        6.9201      0.005   1402.176      0.000         6.910     6.930
# ...

# %%
# by history
model = sm.OLS.from_formula("real_hr_earns ~ age + sex + race + married + productivity + either_history"
                            "+  D_0 + D_1 + D_2", df[df.real_hr_earns > 0])
res = model.fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ...
# Dep. Variable:     np.log(real_hr_earns)   R-squared:                       0.079
# Model:                               OLS   Adj. R-squared:                  0.079
# Method:                    Least Squares   F-statistic:                 1.340e+04
# Date:                   Tue, 03 Dec 2013   Prob (F-statistic):               0.00
# Time:                           20:22:56   Log-Likelihood:            -1.2337e+06
# No. Observations:                1406451   AIC:                         2.467e+06
# Df Residuals:                    1406441   BIC:                         2.468e+06
# Df Model:                              9
# ...
#                      coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------
# Intercept          6.9250      0.005   1405.588      0.000         6.915     6.935
# ...

# %%
rf = df.reset_index()
g = rf.groupby(['qmonth', 'either_history', 'edu', 'age', 'sex', 'race', 'expr'])
r = g['earnings'].agg(['median', 'count'])
r = r.sort_index()

# %%
r.head()
# Out:
#                                                  median  count
# qmonth     either_history edu age sex race expr
# 1996-01-01 -1             32  40  1   1    30     36000      1
#                           33  33  1   1    21     17000      1
#                               54  1   1    42     23076      1
#                           34  31  2   1    17     12000      1
#                           35  25  1   1    10     50000      1
#
# [5 rows x 2 columns]

# %%
w_e = df[df['either_history'] == 0]
w_u = df[df['either_history'] == 1]

# %%
w_u.groupby(['stamp'])['age'].mean().plot(label='unemployed')
w_e.groupby(['stamp'])['age'].mean().plot(label='employed')
plt.legend()

# %%
w_u.groupby(['stamp'])['sex'].mean().plot(label='unemployed')
w_e.groupby(['stamp'])['sex'].mean().plot(label='employed')
plt.legend()

# %%
w_u.groupby(['stamp'])['edu'].mean().plot(label='unemployed')
w_e.groupby(['stamp'])['edu'].mean().plot(label='employed')
plt.legend()

# %%
df.industry.head()
# Out:
# qmonth      HRHHID        HRHHID2  PULINENO
# 1996-01-01  1.760204e+10  65001    1           48
#                                    2           48
#             1.670991e+11  65001    1           44
#             2.670991e+11  65001    1           29
#             4.670991e+11  65001    1           48
# Name: industry, dtype: float64

# %%
res = df.reset_index()
c = res.groupby(['qmonth', 'industry'])['earnings'].agg('count')

# %%
c.ix['2003-01-01':'2012-07-01'].unstack()[c.unstack().columns[:10]].plot()

# %%
import vincent
vincent.core.initialize_notebook()

# %%
data = replace_categorical(c.ix['2003-01-01':'2012-07-01'].unstack(), kind='industry', columns=True)

# %%
x =data.sum(0)
x.sort(ascending=False)
other_ids = x[x < 10000].index

# %%
x
# Out:
# industry
# Educational services                                       97436
# Retail trade                                               85179
# Health care services, except hospitals                     59292
# Public administration                                      57058
# Construction                                               51684
# Professional and  technical services                       51339
# Hospitals                                                  47002
# Transportation and warehousing                             40134
# Finance                                                    31723
# Wholesale trade                                            28466
# Food services and drinking places                          28324
# Administrative and support services                        25144
# Insurance                                                  18560
# Social assistance                                          17065
# ...

# %%
data['other'] = data[other_ids].sum(1)
top = data[data.columns - other_ids]

# %%
b = vincent.Bar(top.sum(0))
b.display()
# Out:
# <div id="vis62642"></div>

# %%
a = vincent.StackedArea(data)
a.legend('Industry')
a.display()
# Out:
# <div id="vis28363"></div>

# %%
a = vincent.StackedArea(top)
a.legend('Industry')
a.display()
# Out:
# <div id="vis51201"></div>

# %%
df.idf.industry.unique
# Out:
# array([ 48.,  44.,  29.,  18.,   9.,  21.,  50.,  30.,  46.,  39.,  36.,
#         35.,   1.,  33.,   2.,  12.,   4.,  40.,  32.,  43.,  41.,  34.,
#         11.,  37.,  31.,  15.,  38.,  51.,  17.,  42.,  45.,  14.,  24.,
#         27.,  19.,  25.,   6.,   7.,  22.,  49.,   5.,   3.,  28.,  13.,
#          8.,  23.,  16.,  26.,  47.,  20.,  10.])

# %%
fig, ax = plt.subplots(figsize=(13, 8))
weighted.groupby(level='qmonth').sum().plot(label='weighted', ax=ax)
raw.plot(label='raw', ax=ax)
ax.legend()

# %%
k = sm.nonparametric.KDEUnivariate(df.og_weight)
k.fit()
fig, ax = plt.subplots(figsize=(13, 8))
ax.plot(k.support, k.density)

# %% [markdown]
# # With Quarters

# %%
with pd.get_store('/Volumes/HDD/Users/tom/DataStorage/CPS/analyzed/clean.h5') as store:
    trim = store.select('trim')

# %%
mod = sm.OLS.from_formula("np.log(real_hr_earns) ~ age + sex_d + race_d +"
                          "married_d + edu_bin + expr + expr_2 +"
                          "expr_3 + expr_4 + Q1 + Q2 + Q3", trim)
res = mod.fit()
res.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                       Results: Ordinary least squares
# ...
# Model:              OLS                   AIC:                2162216.0190
# Dependent Variable: np.log(real_hr_earns) BIC:                2162375.8687
# No. Observations:   1617075               Log-Likelihood:     -1.0811e+06
# Df Model:           12                    F-statistic:        5.443e+04
# Df Residuals:       1617062               Prob (F-statistic): 0.00
# R-squared:          0.288                 Scale:              0.22296
# Adj. R-squared:     0.288
# -----------------------------------------------------------------------------
#               Coef.     Std.Err.        t        P>|t|      [0.025     0.975]
# -----------------------------------------------------------------------------
# Intercept     6.0024      0.0069     872.3278    0.0000     5.9889     6.0159
# age           0.0504      0.0004     132.0140    0.0000     0.0497     0.0511
# ...

# %%
trim['wage_index'] = res.resid
trim.reset_index().groupby(['qmonth', 'either_history'])['wage_index'].mean().unstack().plot()
# Out:
# -c:1: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead

# %%
trim.reset_index().groupby(['qmonth', 'either_history'])['wage_index'].mean().unstack().diff().plot()

# %%
with pd.get_store('/Volumes/HDD/Users/tom/DataStorage/CPS/analyzed/analyzed_store.h5') as store:
    prod = store.select('major_sectors_output_per_hour')

prod = np.log(prod)

# %%
by_hist = trim.reset_index().groupby(['qmonth', 'either_history'])['wage_index'].mean().unstack()
df_ss = pd.concat([by_hist, prod], axis=1).dropna().rename(columns={0: 'from_e', 1: 'from_n'})

# %%
df_ss.head()
# Out:
#               from_e    from_n   durable  nondurable  business
# 1996-01-01 -0.113069 -0.320173  4.098270    4.234614  4.260452
# 1996-04-01 -0.108377 -0.300040  4.108165    4.233976  4.272323
# 1996-07-01 -0.107981 -0.276582  4.126263    4.239656  4.276541
# 1996-10-01 -0.088246 -0.335053  4.132379    4.248367  4.276638
# 1997-01-01 -0.079403 -0.304661  4.146478    4.263750  4.273940
#
# [5 rows x 5 columns]

# %%
mod_e = sm.OLS.from_formula("from_e ~ business", df_ss)
res_e = mod_e.fit()
res_e.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 from_e   R-squared:                       0.920
# Model:                            OLS   Adj. R-squared:                  0.919
# Method:                 Least Squares   F-statistic:                     779.6
# Date:                Tue, 10 Dec 2013   Prob (F-statistic):           5.61e-39
# Time:                        13:28:01   Log-Likelihood:                 171.31
# No. Observations:                  70   AIC:                            -338.6
# Df Residuals:                      68   BIC:                            -334.1
# Df Model:                           1
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -2.5235      0.091    -27.843      0.000        -2.704    -2.343
# ...

# %%
mod_n = sm.OLS.from_formula("from_n ~ business", df_ss)
res_n = mod_n.fit()
res_n.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 from_n   R-squared:                       0.902
# Model:                            OLS   Adj. R-squared:                  0.901
# Method:                 Least Squares   F-statistic:                     628.3
# Date:                Tue, 10 Dec 2013   Prob (F-statistic):           4.53e-36
# Time:                        13:27:50   Log-Likelihood:                 159.66
# No. Observations:                  70   AIC:                            -315.3
# Df Residuals:                      68   BIC:                            -310.8
# Df Model:                           1
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -2.8517      0.107    -26.643      0.000        -3.065    -2.638
# ...

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(figsize=(20, 15), ncols=2, nrows=2)

ax1.scatter(res_e.fittedvalues, res_e.resid)
ax2.scatter(res_n.fittedvalues, res_n.resid)
ax3.plot(res_e.resid)
ax4.plot(res_n.resid)
fig.tight_layout()

# %%
prod.plot()

# %%
fig, (ax1, ax2) = plt.subplots(figsize=(20, 8), ncols=2)
df_ss.plot(kind='scatter', x='business', y='from_e', ax=ax1)
df_ss.diff().plot(kind='scatter', x='business', y='from_e', ax=ax2)

# %%
df_ss[['from_e', 'from_n', 'business']].plot(secondary_y='business')

# %%
diffed = df_ss.diff()
# business_shifted

# %%
diffed.head()
# Out:
#               from_e    from_n   durable  nondurable  business
# 1996-01-01       NaN       NaN       NaN         NaN       NaN
# 1996-04-01  0.004692  0.020133  0.009895   -0.000638  0.011871
# 1996-07-01  0.000396  0.023457  0.018098    0.005680  0.004218
# 1996-10-01  0.019735 -0.058470  0.006116    0.008710  0.000097
# 1997-01-01  0.008842  0.030391  0.014100    0.015383 -0.002698
#
# [5 rows x 5 columns]

# %%
diffed['business_shifted'] = diffed.business.shift(1)

# %%
fig, (ax1, ax2) = plt.subplots(figsize=(20, 8), ncols=2)
diffed.plot(kind='scatter', x='business', y='from_e', ax=ax1)
diffed.plot(kind='scatter', x='business_shifted', y='from_e', ax=ax2)

# %%
df_ss['trend'] = np.arange(df_ss.shape[0])
mod_t = sm.OLS.from_formula("from_e ~ business", df_ss)
res_t = mod_n.fit()
res_t.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 from_n   R-squared:                       0.902
# Model:                            OLS   Adj. R-squared:                  0.901
# Method:                 Least Squares   F-statistic:                     628.3
# Date:                Tue, 10 Dec 2013   Prob (F-statistic):           4.53e-36
# Time:                        13:29:30   Log-Likelihood:                 159.66
# No. Observations:                  70   AIC:                            -315.3
# Df Residuals:                      68   BIC:                            -310.8
# Df Model:                           1
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -2.8517      0.107    -26.643      0.000        -3.065    -2.638
# ...

# %%
plt.plot(res_t.resid)

# %%
fig, ax = plt.subplots(figsize=(16, 9))
df_ss[['employed', 'business']].diff().plot(secondary_y='business', ax=ax)

# %%
fig, ax = plt.subplots(figsize=(16, 9))
df_ss_med[['employed', 'business']].diff().plot(secondary_y='business', ax=ax)

# %%
df_ss.employed.diff().plot(label='mean')
df_ss_med.employed.diff().plot(label='median')
plt.legend()

# %%
trim.reset_index().groupby(['qmonth', 'either_history'])['ln_real_hr_earns_d'].mean().unstack().diff().plot()
