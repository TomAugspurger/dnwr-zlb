# %%
# %pylab inline --no-import-all
# %load_ext autoreload
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %autoreload
from __future__ import division, print_function

from datetime import datetime
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from helpers import *

# %%
with open('../panel_construction/settings.txt', 'r') as f:
    settings = json.load(f)

earn_store = pd.HDFStore(settings['earn_store_path'])
panel_store = pd.HDFStore(settings['panel_store_path'])
cps_store = pd.HDFStore(settings['store_path'])

# %% [markdown]
# Links:
#
# - [Single Panel](http://127.0.0.1:8888/b96262f8-d714-4a96-a3cd-e02c7364d82c#Working-With-Panels:-Single-Example)
# - [From the Raw](http://127.0.0.1:8888/aa704d7a-0ed8-4491-a7ed-fa7a8cc80ed0#From-The-raw-CPS-Files)

# %%
# get missing keys:
eks = earn_store.keys()
pks = panel_store.keys()
cks = panel_store.keys()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-c80327509fc8> in <module>()
#       1 # get missing keys:
# ----> 2 eks = earn_store.keys()
#       3 pks = panel_store.keys()
#       4 cks = panel_store.keys()
#
# /Users/tom/Envs/statsmodels/lib/python2.7/site-packages/pandas/pandas/io/pytables.pyc in keys(self)
#     455         objects stored in the HDFStore. These are ABSOLUTE path-names (e.g. have the leading '/'
#     456         """
# --> 457         return [n._v_pathname for n in self.groups()]
#     458
#     459     def items(self):
#
# /Users/tom/Envs/statsmodels/lib/python2.7/site-packages/pandas/pandas/io/pytables.pyc in groups(self)
#     933         _tables()
#     934         self._check_if_open()
# --> 935         return [g for g in self._handle.walkNodes() if getattr(g._v_attrs, 'pandas_type', None) or getattr(
#     936             g, 'table', None) or (isinstance(g, _table_mod.table.Table) and g._v_name != u('table'))]
#     937
#
# /Users/tom/Envs/statsmodels/lib/python2.7/site-packages/tables/file.pyc in walk_nodes(self, where, classname)
#    1853             yield self.get_node(where)
#    1854             for group in self.walk_groups(where):
# -> 1855                 for leaf in self.iter_nodes(group):
#    1856                     yield leaf
#    1857         else:  # only nodes of the named type
#
# /Users/tom/Envs/statsmodels/lib/python2.7/site-packages/tables/group.pyc in _f_iter_nodes(self, classname)
#     715         if not classname:
#     716             # Returns all the children alphanumerically sorted
# --> 717             names = sorted(self._v_children.iterkeys())
#     718             for name in names:
#     719                 yield self._v_children[name]
#
# /Users/tom/Envs/statsmodels/lib/python2.7/site-packages/tables/group.pyc in __getattr__(self, name)
#     809             return mydict[name]
#     810         elif name in self._c_lazy_children_attrs:
# --> 811             self._g_add_children_names()
#     812             return mydict[name]
#     813         return self._f_get_child(name)
#
# /Users/tom/Envs/statsmodels/lib/python2.7/site-packages/tables/group.pyc in _g_add_children_names(self)
#     374         # Get the names of *all* child groups and leaves.
#     375         (group_names, leaf_names, link_names, unknown_names) = \
# --> 376             self._g_list_group(self._v_parent)
#     377
#     378         # Separate groups into visible groups and hidden nodes,
#
# KeyboardInterrupt:

# %%
# eks are offset from pks by +1 years. Roll those back
import arrow
eks_comp = [arrow.get(k, 'mYY_MM').replace(years=-1).strftime('/m%Y_%m') for k in eks]

missing_from_pks = set(cks) - set(eks)
missing_from_eks = set(pks) - set(eks)
lost_from_pks_to_eks = missing_from_eks - missing_from_pks
print(missing_from_eks, end='\n\n')
print(missing_from_pks, end='\n\n')
_10', '/m2004_01', '/m2004_02', '/m2004_03', '/m2004_04', '/m2004_05', '/m2004_06', '/m2004_07', '/m2012_10', '/m2012_11', '/m2012_12', '/m1990_09', '/m1990_08', '/m1990_01', '/m1990_03', '/m1990_02', '/m1990_05', '/m1990_04', '/m1990_07', '/m1990_06', '/m1994_12', '/m1994_10', '/m1994_11', '/m2004_12', '/m1989_01', '/m2004_10', '/m2013_01', '/m2013_02', '/m2013_03', '/m2013_04', '/m2013_06', '/m2013_07', '/m2013_08', '/m1990_10', '/m1990_11', '/m1989_09', '/m1991_02', '/m1991_03', '/m1991_01', '/m1991_06', '/m1991_07', '/m1991_04', '/m1991_05', '/m1991_08', '/m1995_11', '/m1995_10', '/m1995_12'])
#
# set([])

# %%
df = earn_store.select('/m2008_02')

# %%
df = sane_names(df, flattened=True)

# %%
cols = ['age1', 'age2', 'year1', 'year2', 'race1', 'race2', 'sex1', 'sex2', 'earnings1', 'earnings2',
          'labor_status1', 'labor_status2']
sub = df[cols]

# %%
sub['flow'] = add_flows(sub.labor_status1, sub.labor_status2)

# %%
sub.head()
# Out:
#                                age1  age2  year1  year2  race1  race2  sex1  \
# HRHHID       HRHHID2 PULINENO
# 167099107896 82001   1           53    54   2007   2008      1      1     1
#                      2           52    53   2007   2008      1      1     2
# 267099107897 82001   1           50    51   2007   2008      1      1     1
#                      2           44    45   2007   2008      1      1     2
#                      3           20    21   2007   2008      1      1     1
#
#                                sex2  earnings1  earnings2  labor_status1  \
# HRHHID       HRHHID2 PULINENO
# 167099107896 82001   1            1      60000      92000              1
#                      2            2      39000      30000              1
# 267099107897 82001   1            1      90000     103000              1
#                      2            2        NaN        NaN              7
#                      3            1      37000      50000              1
#
#                                labor_status2 flow
# HRHHID       HRHHID2 PULINENO
# 167099107896 82001   1                     1   ee
#                      2                     1   ee
# 267099107897 82001   1                     1   ee
#                      2                     7   nn
#                      3                     1   ee

# %%
sub.groupby('flow')[['earnings1', 'earnings2']].mean()
# Out:
#          earnings1     earnings2
# flow
# ee    81298.624944  84986.942415
# en    50825.763578           NaN
# eu    52355.414414           NaN
# ne             NaN  31868.782456
# nn             NaN           NaN
# nu             NaN           NaN
# ue             NaN  63873.602151
# un             NaN           NaN
# uu             NaN           NaN

# %%
sub.groupby('flow')['flow'].count()
# Out:
# flow
# ee      5124
# en       362
# eu       116
# ne       321
# nn      2646
# nu        78
# ue       100
# un        45
# uu         7
# dtype: int64

# %% [markdown]
# # Working With Panels: Single Example

# %%
wp = panel_store.select('/m2008_02')
wp
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 8 (items) x 18686 (major_axis) x 69 (minor_axis)
# Items axis: 1 to 8
# Major_axis axis: (13902076671, 84001, -1) to (999990642340730, 84001, 3)
# Minor_axis axis: PROLDRRP to PELKDUR

# %%
wp = sane_names(wp)
sub = wp.ix[:, :, ('age', 'year', 'month', 'labor_status', 'earnings', 'race', 'sex', 'married')]
sub
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 8 (items) x 18686 (major_axis) x 8 (minor_axis)
# Items axis: 1 to 8
# Major_axis axis: (13902076671, 84001, -1) to (999990642340730, 84001, 3)
# Minor_axis axis: age to married

# %%
sub.minor_xs('labor_status').dropna().head()
# Out:
#                               1  2  3  4  5  6  7  8
# HRHHID      HRHHID2 PULINENO
# 23706033651 84001   1         7  7  7  7  7  7  7  7
#                     2         1  1  1  1  1  1  1  1
#                     8         7  5  5  5  5  5  5  5
# 67099103896 84001   1         1  1  1  1  1  1  1  1
#                     2         1  1  1  1  1  5  5  1

# %%
lab = sub.minor_xs('labor_status')
sub = add_flows_panel(sub, inplace=True)
sub[2].head()
# Out:
#                               age  year month labor_status earnings race  sex  \
# HRHHID      HRHHID2 PULINENO
# 13902076671 84001   -1        NaN   NaN   NaN          NaN      NaN  NaN  NaN
# 23408025621 84001   -1        NaN   NaN   NaN          NaN      NaN  NaN  NaN
# 23706033651 84001    1         41  2008     3            7      NaN    4    2
#                      2         41  2008     3            1      NaN    4    1
#                      3         13  2008     3          NaN      NaN    4    1
#
#                              married flow
# HRHHID      HRHHID2 PULINENO
# 13902076671 84001   -1           NaN  NaN
# 23408025621 84001   -1           NaN  NaN
# 23706033651 84001    1             1   nn
#                      2             1   ee
#                      3           NaN  NaN

# %%
sub.minor_xs('flow').head(10)
# Out:
#                                1    2    3    4    5    6    7    8
# HRHHID      HRHHID2 PULINENO
# 13902076671 84001   -1       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 23408025621 84001   -1       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 23706033651 84001    1       NaN   nn   nn   nn   nn   nn   nn   nn
#                      2       NaN   ee   ee   ee   ee   ee   ee   ee
#                      3       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#                      4       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#                      5       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#                      6       NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#                      7       NaN   nn   nn   nn  NaN  NaN  NaN  NaN
#                      8       NaN   nn   nn   nn   nn   nn   nn   nn

# %%
df = sub.minor_xs('flow')
x = df.reset_index()
df = (x.loc[~(x['PULINENO'] == -1)]).set_index(['HRHHID', 'HRHHID2', 'PULINENO'])
print(df.head())
df = df.dropna(how='all', axis=[0, 1])
all_clean = df.dropna(how='any', axis=0)
all_clean.head()
# Out:
#                                1    2    3    4    5    6    7    8
# HRHHID      HRHHID2 PULINENO
# 23706033651 84001   1        NaN   nn   nn   nn   nn   nn   nn   nn
#                     2        NaN   ee   ee   ee   ee   ee   ee   ee
#                     3        NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#                     4        NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#                     5        NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#                                2   3   4   5   6   7   8
# HRHHID      HRHHID2 PULINENO
# 23706033651 84001   1         nn  nn  nn  nn  nn  nn  nn
#                     2         ee  ee  ee  ee  ee  ee  ee
#                     8         nn  nn  nn  nn  nn  nn  nn
# 67099103896 84001   1         ee  ee  ee  ee  ee  ee  ee
#                     2         ee  ee  ee  ee  en  nn  ne

# %%
# status rather than flow
df = wp.minor_xs('labor_status')
x = df.reset_index()
df = (x.loc[~(x['PULINENO'] == -1)]).set_index(['HRHHID', 'HRHHID2', 'PULINENO'])
print(df.head())
df = df.dropna(how='all', axis=[0, 1])
clean = df.dropna(how='any', axis=0)
clean.head()
# Out:
#                                1   2   3   4   5   6   7   8
# HRHHID      HRHHID2 PULINENO
# 23706033651 84001   1          7   7   7   7   7   7   7   7
#                     2          1   1   1   1   1   1   1   1
#                     3        NaN NaN NaN NaN NaN NaN NaN NaN
#                     4        NaN NaN NaN NaN NaN NaN NaN NaN
#                     5        NaN NaN NaN NaN NaN NaN NaN NaN
#                               1  2  3  4  5  6  7  8
# HRHHID      HRHHID2 PULINENO
# 23706033651 84001   1         7  7  7  7  7  7  7  7
#                     2         1  1  1  1  1  1  1  1
#                     8         7  5  5  5  5  5  5  5
# 67099103896 84001   1         1  1  1  1  1  1  1  1
#                     2         1  1  1  1  1  5  5  1

# %%
import vincent
vincent.core.initialize_notebook()

# %%
labels = {1: 'employed', 2: 'employed', 3: 'unemployed', 4: 'unemployed', 5: 'nilf', 6: 'nilf', 7: 'nilf'}
cts = clean.replace(labels).apply(lambda x: pd.value_counts(x))
cts = cts.sort_index()

# %%
stacked = vincent.StackedArea(cts.T)
stacked.axis_titles(x='Index', y='Value')
stacked.legend(title='Employment Status')
stacked.display()
# Out:
# <div id="vis6630"></div>

# %%
# With Attrition
labels = {1: 'employed', 2: 'employed', 3: 'unemployed', 4: 'unemployed', 5: 'nilf', 6: 'nilf', 7: 'nilf'}
cts = df.replace(labels).apply(lambda x: pd.value_counts(x))
cts = cts.sort_index()
cts.T

stacked = vincent.StackedArea(cts.T)
stacked.axis_titles(x='Index', y='Value')
stacked.legend(title='Employment Status')
stacked.display()
# Out:
# <div id="vis29910"></div>

# %% [markdown]
# # From The raw CPS Files

# %%
import arrow
# %autoreload

# %%
cks = sorted(filter(lambda x: x.startswith('/monthly/data/'), cps_store.keys()))

# %%
import itertools as it
cks_ = it.dropwhile(lambda x: not x.startswith('/monthly/data/m2010_01'), cks)

# %%
res = pd.concat([labor_status_value_counts(cps_store, x.split('/')[-1].lstrip('m')) for x in cks_], axis=1).T

# %%
debug
# Out:
# > /Users/tom/Dropbox/Economics/inflation_in_recession/dnwr_zlb/data_wrangling/cps_wrangling/analysis/helpers.py(174)labor_status_value_counts()
#     173     # cts = cts.sort_index().T
# --> 174     date = datetime(int(df.year.iloc[0]), int(df.month.iloc[0]), 1)
#     175     cts.name = date
# ipdb> df.year
# HRHHID        HUHHNUM  PULINENO
# NaN           NaN      12          1994
#               1        NaN         1994
# 1.165997e+07  1        1           1994
# 2.149561e+07  1        1           1994
#                        2           1994
#                        3           1994
#                        4           1994
# 4.140560e+07  1        1           1994
#                        2           1994
#                        3           1994
#                        4           1994
# 4.409101e+07  1        1           1994
#                        2           1994
#                        3           1994
# 6.238012e+07  1        1           1994
# ...
# 9.996777e+11  1        2           1994
#                        3           1994
#                        4           1994
# 9.996778e+11  1        1           1994
#                        2           1994
# 9.998502e+11  1        1           1994
#                        2           1994
#                        3           1994
#                        4           1994
#                        5           1994
# 9.998509e+11  1        1           1994
#                        2           1994
# 9.998594e+11  2        1           1994
#                        2           1994
# 9.999991e+11  1        4           1994
# Name: year, Length: 105231, dtype: int64
# ipdb> df.month.head()
# HRHHID        HUHHNUM  PULINENO
# NaN           NaN      12         NaN
#               1        NaN          1
# 1.165997e+07  1        1            7
# 2.149561e+07  1        1            7
#                        2            7
# Name: month, dtype: float64
# ipdb> q

# %%
stacked = vincent.StackedArea(res)
stacked.axis_titles(x='Date', y='Count')
stacked.legend(title='Employment Status')
stacked.display()
# Out:
# <div id="vis23483"></div>
