# %%
# %matplotlib inline

# %%
import pandas as pd
import seaborn as sns
import statsmodels.api as sm

from add_rec_bars import add_rec_bars
from helpers import make_df_ss

# %%
vr = pd.read_csv('/Users/tom/Desktop/do_results.zip Folder/wagedata_all2560_www-2.csv')
vr['time'] = pd.to_datetime(vr.year.astype(str) + '-' + vr.qrt.astype(str) + '-01')
vr = vr.set_index('time')
vr = vr.ix['1996':]

# %%
with pd.get_store('/Volumes/HDD/Users/tom/DataStorage/CPS/analyzed/clean.h5') as store:
    df = store.select('merged')
    
with pd.get_store('/Volumes/HDD/Users/tom/DataStorage/CPS/analyzed/analyzed_store.h5') as store:
    deflator = store.select('deflator')['deflator']
    deflator.index.set_names(['qmonth'], inplace=True)

# %%
df.head()
# Out:
#                                           Q1  Q2  Q3  age  earnhre  earnings  \
# qmonth     HRHHID       HRHHID2 PULINENO
# 1996-01-01 17602036881  65001   1          1   0   0   43      NaN    576.92
#                                 2          1   0   0   47      NaN   1173.07
#            167099107896 65001   1          1   0   0   57     3700    992.30
#            167099108898 65001   2          1   0   0   33     1800    720.00
#            172100699191 66001   1          1   0   0   45     1343    671.50
#
#                                           earnwke       earnwt  edu  \
# qmonth     HRHHID       HRHHID2 PULINENO
# 1996-01-01 17602036881  65001   1             576  8436.624023   42
#                                 2            1173  8759.862305   43
#            167099107896 65001   1             992  7238.746582   43
#            167099108898 65001   2             720  7750.153320   43
#            172100699191 66001   1             671  6071.914551   43
#
#                                           either_history  ethnic  expr  flow  \
# qmonth     HRHHID       HRHHID2 PULINENO
# 1996-01-01 17602036881  65001   1                      0       8    23     1
#                                 2                      0       8    23     1
#            167099107896 65001   1                      0       8    33     1
#            167099108898 65001   2                      0       3     9     1
#            172100699191 66001   1                      0       8    21     1
#
#                                           hourslw  ihigrdc  ind02  industry  \
# qmonth     HRHHID       HRHHID2 PULINENO
# 1996-01-01 17602036881  65001   1              40      NaN    NaN        48
#                                 2              48      NaN    NaN        48
#            167099107896 65001   1              40      NaN    NaN        44
#            167099108898 65001   2              40      NaN    NaN        42
#            172100699191 66001   1              54      NaN    NaN        12
#
#                                           labor_status  lfsr94  marital
# qmonth     HRHHID       HRHHID2 PULINENO
# 1996-01-01 17602036881  65001   1                    1       1        1 ...
#                                 2                    1       1        1 ...
#            167099107896 65001   1                    1       1        7 ...
#            167099108898 65001   2                    1       1        1 ...
#            172100699191 66001   1                    1       1        1 ...
#
# [5 rows x 41 columns]

# %%
lr_wage_agg = df.lr_wage.groupby(level='qmonth').agg(['mean', 'median'])

ax = lr_wage_agg.plot()
ax = vr.lrwage_allm_mn.plot(label='his', ax=ax)
plt.legend()

# %%
formula_fs = ("lr_wage ~ age + sex_d + race_d + married_d + edu_bin"
              " + expr + expr_2 + expr_3 + expr_4")

model = sm.OLS.from_formula(formula_fs, df)
res = model.fit()

# %%
res.params.index
# Out:
# Index([u'Intercept', u'age', u'sex_d', u'race_d', u'married_d', u'edu_bin', u'expr', u'expr_2', u'expr_3', u'expr_4'], dtype='object')

# %%
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                lr_wage   R-squared:                       0.287
# Model:                            OLS   Adj. R-squared:                  0.287
# Method:                 Least Squares   F-statistic:                 6.790e+04
# Date:                Tue, 17 Dec 2013   Prob (F-statistic):               0.00
# Time:                        09:58:48   Log-Likelihood:            -1.0064e+06
# No. Observations:             1516498   AIC:                         2.013e+06
# Df Residuals:                 1516488   BIC:                         2.013e+06
# Df Model:                           9
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      1.4293      0.007    202.866      0.000         1.415     1.443
# age            0.0506      0.000    128.744      0.000         0.050     0.051
# sex_d         -0.2489      0.001   -324.444      0.000        -0.250    -0.247
# race_d        -0.0966      0.001    -70.604      0.000        -0.099    -0.094
# married_d      0.0615      0.001     72.767      0.000         0.060     0.063
# edu_bin        0.0722      0.001     85.338      0.000         0.071     0.074
# expr          -0.0199      0.001    -23.068      0.000        -0.022    -0.018
# expr_2        -0.0009   6.19e-05    -14.440      0.000        -0.001    -0.001
# expr_3      9.799e-06   1.99e-06      4.925      0.000       5.9e-06  1.37e-05
# expr_4     -1.951e-08   2.18e-08     -0.895      0.371     -6.22e-08  2.32e-08
# ==============================================================================
# Omnibus:                    18194.157   Durbin-Watson:                   1.858
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            25617.634
# Skew:                          -0.156   Prob(JB):                         0.00
# Kurtosis:                       3.555   Cond. No.                     1.74e+07
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 1.74e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
with pd.get_store('/Volumes/HDD/Users/tom/DataStorage/CPS/analyzed/analyzed_store.h5') as store:
    prod = store.select('major_sectors_output_per_hour')
    u_rate = store.select('u_rate')

lrprod = np.log(prod.div(deflator, axis='index') * 100).diff()

# %%
# Construct second stage DataFrame
df_ss = make_df_ss(df, res.params, lrprod)

# %%
df_ss.head()
# Out:
#                 from_e                                                      \
#             wage_index   durable  nondurable  business  Q_1  Q_2  Q_3  Q_4
# qmonth
# 1996-01-01   -0.004019       NaN         NaN       NaN    1    0    0    0
# 1996-04-01   -0.004128  0.006079   -0.004453  0.008056    0    1    0    0
# 1996-07-01    0.007142  0.014752    0.002335  0.000872    0    0    1    0
# 1996-10-01    0.010339  0.001443    0.004038 -0.004575    0    0    0    1
# 1997-01-01   -0.002962  0.008436    0.009720 -0.008361    1    0    0    0
#
#                 from_n                                                      \
#             wage_index   durable  nondurable  business  Q_1  Q_2  Q_3  Q_4
# qmonth
# 1996-01-01    0.015008       NaN         NaN       NaN    1    0    0    0
# 1996-04-01   -0.009821  0.006079   -0.004453  0.008056    0    1    0    0
# 1996-07-01   -0.001271  0.014752    0.002335  0.000872    0    0    1    0
# 1996-10-01    0.013957  0.001443    0.004038 -0.004575    0    0    0    1
# 1997-01-01   -0.007158  0.008436    0.009720 -0.008361    1    0    0    0
#
#                   all_
#             wage_index   durable  nondurable  business
# qmonth
# 1996-01-01   -0.003913       NaN         NaN       NaN ...
# 1996-04-01   -0.004262  0.006079   -0.004453  0.008056 ...
# 1996-07-01    0.006883  0.014752    0.002335  0.000872 ...
# 1996-10-01    0.011419  0.001443    0.004038 -0.004575 ...
# 1997-01-01   -0.004078  0.008436    0.009720 -0.008361 ...
#
# [5 rows x 24 columns]

# %%
cts = df.groupby('either_history')['age'].count()
print(cts)
print(cts.sum())
# Out:
# either_history
# 0                 1447530
# 1                   68973
# dtype: int64
# 1516503

# %%
mod_ss_e = sm.OLS.from_formula('wage_index ~ business + Q_1 + Q_2 + Q_3', df_ss['from_e'].dropna())
res_ss_e = mod_ss_e.fit()
res_ss_e.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             wage_index   R-squared:                       0.288
# Model:                            OLS   Adj. R-squared:                  0.240
# Method:                 Least Squares   F-statistic:                     5.970
# Date:                Tue, 17 Dec 2013   Prob (F-statistic):           0.000421
# Time:                        11:06:38   Log-Likelihood:                 282.16
# No. Observations:                  64   AIC:                            -554.3
# Df Residuals:                      59   BIC:                            -543.5
# Df Model:                           4
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      0.0018      0.001      2.230      0.030         0.000     0.003
# business       0.0538      0.048      1.130      0.263        -0.041     0.149
# Q_1           -0.0035      0.001     -3.111      0.003        -0.006    -0.001
# Q_2           -0.0012      0.001     -1.076      0.286        -0.003     0.001
# Q_3            0.0013      0.001      1.171      0.246        -0.001     0.003
# ==============================================================================
# Omnibus:                        1.241   Durbin-Watson:                   2.449
# Prob(Omnibus):                  0.538   Jarque-Bera (JB):                0.763
# Skew:                           0.256   Prob(JB):                        0.683
# Kurtosis:                       3.156   Cond. No.                         136.
# ==============================================================================
# """

# %%
mod_ss_n = sm.OLS.from_formula('wage_index ~ business + Q_1 + Q_2 + Q_3', df_ss['from_n'].dropna())
res_ss_n = mod_ss_n.fit()
res_ss_n.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             wage_index   R-squared:                       0.468
# Model:                            OLS   Adj. R-squared:                  0.432
# Method:                 Least Squares   F-statistic:                     12.96
# Date:                Tue, 17 Dec 2013   Prob (F-statistic):           1.23e-07
# Time:                        11:06:41   Log-Likelihood:                 180.77
# No. Observations:                  64   AIC:                            -351.5
# Df Residuals:                      59   BIC:                            -340.7
# Df Model:                           4
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -0.0188      0.004     -4.796      0.000        -0.027    -0.011
# business       0.3332      0.232      1.437      0.156        -0.131     0.797
# Q_1            0.0136      0.005      2.501      0.015         0.003     0.024
# Q_2            0.0342      0.005      6.438      0.000         0.024     0.045
# Q_3            0.0265      0.005      4.925      0.000         0.016     0.037
# ==============================================================================
# Omnibus:                        0.233   Durbin-Watson:                   2.936
# Prob(Omnibus):                  0.890   Jarque-Bera (JB):                0.250
# Skew:                           0.133   Prob(JB):                        0.883
# Kurtosis:                       2.849   Cond. No.                         136.
# ==============================================================================
# """

# %%
mod_ss_a = sm.OLS.from_formula('wage_index ~ business + Q_1 + Q_2 + Q_3', df_ss['all_'].dropna())
res_ss_a = mod_ss_a.fit()
res_ss_a.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             wage_index   R-squared:                       0.356
# Model:                            OLS   Adj. R-squared:                  0.313
# Method:                 Least Squares   F-statistic:                     8.161
# Date:                Tue, 17 Dec 2013   Prob (F-statistic):           2.63e-05
# Time:                        14:02:38   Log-Likelihood:                 279.44
# No. Observations:                  64   AIC:                            -548.9
# Df Residuals:                      59   BIC:                            -538.1
# Df Model:                           4
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      0.0017      0.001      1.978      0.053     -1.94e-05     0.003
# business       0.0702      0.050      1.414      0.163        -0.029     0.169
# Q_1           -0.0042      0.001     -3.582      0.001        -0.007    -0.002
# Q_2           -0.0004      0.001     -0.386      0.701        -0.003     0.002
# Q_3            0.0016      0.001      1.365      0.177        -0.001     0.004
# ==============================================================================
# Omnibus:                        3.835   Durbin-Watson:                   2.451
# Prob(Omnibus):                  0.147   Jarque-Bera (JB):                2.913
# Skew:                           0.456   Prob(JB):                        0.233
# Kurtosis:                       3.509   Cond. No.                         136.
# ==============================================================================
# """

# %% [markdown]
# # By Sector

# %% [markdown]
# Durables include 11,5,6,6,7,8,9,10,12,13.
#
# Nondurables are 14,15,16,17,17,18,19,20 (see `notes.md`)

# %%
ax = prod.plot()
add_rec_bars(ax)

# %%
# First Stage

durable_codes = [11, 5, 6, 7, 8, 9, 10, 12, 13]
df_fs_d = df[df.industry.isin(durable_codes)]

nondurable_codes = [14, 15, 16, 17, 18, 19, 20]
df_fs_nd = df[df.industry.isin(nondurable_codes)]

mod_fs_d = sm.OLS.from_formula(formula_fs, df_fs_d)
res_fs_d = mod_fs_d.fit()

mod_fs_nd = sm.OLS.from_formula(formula_fs, df_fs_nd)
res_fs_nd = mod_fs_nd.fit()

# %%
res_fs_d.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                lr_wage   R-squared:                       0.356
# Model:                            OLS   Adj. R-squared:                  0.356
# Method:                 Least Squares   F-statistic:                     7919.
# Date:                Tue, 17 Dec 2013   Prob (F-statistic):               0.00
# Time:                        14:27:56   Log-Likelihood:                -68713.
# No. Observations:              129015   AIC:                         1.374e+05
# Df Residuals:                  129005   BIC:                         1.375e+05
# Df Model:                           9
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      1.3058      0.023     57.309      0.000         1.261     1.350
# age            0.0612      0.001     50.908      0.000         0.059     0.064
# sex_d         -0.2175      0.003    -83.064      0.000        -0.223    -0.212
# race_d        -0.1388      0.005    -29.933      0.000        -0.148    -0.130
# married_d      0.0618      0.003     23.508      0.000         0.057     0.067
# edu_bin        0.0705      0.003     27.965      0.000         0.066     0.075
# expr          -0.0396      0.003    -12.688      0.000        -0.046    -0.033
# expr_2        -0.0001      0.000     -0.568      0.570        -0.001     0.000
# expr_3     -1.398e-05   6.59e-06     -2.121      0.034     -2.69e-05 -1.06e-06
# expr_4      2.435e-07   6.95e-08      3.506      0.000      1.07e-07   3.8e-07
# ==============================================================================
# Omnibus:                     2716.298   Durbin-Watson:                   1.932
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4629.997
# Skew:                          -0.187   Prob(JB):                         0.00
# Kurtosis:                       3.849   Cond. No.                     2.06e+07
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 2.06e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
res_fs_nd.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                lr_wage   R-squared:                       0.376
# Model:                            OLS   Adj. R-squared:                  0.376
# Method:                 Least Squares   F-statistic:                     4385.
# Date:                Tue, 17 Dec 2013   Prob (F-statistic):               0.00
# Time:                        14:27:57   Log-Likelihood:                -36902.
# No. Observations:               65613   AIC:                         7.382e+04
# Df Residuals:                   65603   BIC:                         7.391e+04
# Df Model:                           9
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      1.3850      0.029     48.131      0.000         1.329     1.441
# age            0.0537      0.001     37.391      0.000         0.051     0.056
# sex_d         -0.2270      0.004    -64.684      0.000        -0.234    -0.220
# race_d        -0.1496      0.006    -25.273      0.000        -0.161    -0.138
# married_d      0.0703      0.004     18.741      0.000         0.063     0.078
# edu_bin        0.0850      0.003     26.379      0.000         0.079     0.091
# expr          -0.0323      0.004     -7.319      0.000        -0.041    -0.024
# expr_2      5.169e-05      0.000      0.172      0.864        -0.001     0.001
# expr_3     -2.096e-05   8.95e-06     -2.342      0.019     -3.85e-05 -3.42e-06
# expr_4      3.136e-07   9.18e-08      3.415      0.001      1.34e-07  4.94e-07
# ==============================================================================
# Omnibus:                     1228.190   Durbin-Watson:                   1.938
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2050.205
# Skew:                          -0.171   Prob(JB):                         0.00
# Kurtosis:                       3.796   Cond. No.                     1.89e+07
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 1.89e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
df_ss_d  = make_df_ss(df_fs_d,  res_fs_d.params,  lrprod[['durable']])
df_ss_nd = make_df_ss(df_fs_nd, res_fs_nd.params, lrprod[['nondurable']])

# %%
mod_ss_d_e = sm.OLS.from_formula('wage_index ~ durable + Q_1 + Q_2 + Q_3', df_ss_d['from_e'])
mod_ss_d_n = sm.OLS.from_formula('wage_index ~ durable + Q_1 + Q_2 + Q_3', df_ss_d['from_n'])
mod_ss_d_a = sm.OLS.from_formula('wage_index ~ durable + Q_1 + Q_2 + Q_3', df_ss_d['all_'])

res_ss_d_e = mod_ss_d_e.fit()
res_ss_d_n = mod_ss_d_n.fit()
res_ss_d_a = mod_ss_d_a.fit()

print(res_ss_d_e.summary())
print(res_ss_d_n.summary())
print(res_ss_d_a.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             wage_index   R-squared:                       0.144
# Model:                            OLS   Adj. R-squared:                  0.086
# Method:                 Least Squares   F-statistic:                     2.487
# Date:                Tue, 17 Dec 2013   Prob (F-statistic):             0.0530
# Time:                        14:30:53   Log-Likelihood:                 205.87
# No. Observations:                  64   AIC:                            -401.7
# Df Residuals:                      59   BIC:                            -390.9
# Df Model:                           4
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -0.0005      0.003     -0.175      0.862        -0.006     0.005
# durable       -0.0114      0.080     -0.142      0.887        -0.171     0.148
# Q_1           -0.0024      0.004     -0.659      0.513        -0.010     0.005
# Q_2            0.0079      0.004      2.212      0.031         0.001     0.015
# Q_3            0.0040      0.004      1.105      0.274        -0.003     0.011
# ==============================================================================
# Omnibus:                        0.853   Durbin-Watson:                   2.833
# Prob(Omnibus):                  0.653   Jarque-Bera (JB):                0.314
# Skew:                           0.084   Prob(JB):                        0.855
# Kurtosis:                       3.299   Cond. No.                         69.4
# ==============================================================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             wage_index   R-squared:                       0.178
# Model:                            OLS   Adj. R-squared:                  0.123
# Method:                 Least Squares   F-statistic:                     3.205
# Date:                Tue, 17 Dec 2013   Prob (F-statistic):             0.0190
# Time:                        14:30:53   Log-Likelihood:                 92.442
# No. Observations:                  64   AIC:                            -174.9
# Df Residuals:                      59   BIC:                            -164.1
# Df Model:                           4
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      0.0271      0.016      1.734      0.088        -0.004     0.058
# durable       -0.1410      0.470     -0.300      0.765        -1.081     0.799
# Q_1           -0.0457      0.021     -2.138      0.037        -0.088    -0.003
# Q_2            0.0024      0.021      0.114      0.910        -0.040     0.045
# Q_3           -0.0563      0.021     -2.630      0.011        -0.099    -0.013
# ==============================================================================
# Omnibus:                        0.087   Durbin-Watson:                   2.813
# Prob(Omnibus):                  0.957   Jarque-Bera (JB):                0.225
# Skew:                           0.076   Prob(JB):                        0.893
# Kurtosis:                       2.752   Cond. No.                         69.4
# ==============================================================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             wage_index   R-squared:                       0.169
# Model:                            OLS   Adj. R-squared:                  0.113
# Method:                 Least Squares   F-statistic:                     3.003
# Date:                Tue, 17 Dec 2013   Prob (F-statistic):             0.0253
# Time:                        14:30:53   Log-Likelihood:                 208.12
# No. Observations:                  64   AIC:                            -406.2
# Df Residuals:                      59   BIC:                            -395.4
# Df Model:                           4
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      0.0007      0.003      0.285      0.777        -0.004     0.006
# durable       -0.0058      0.077     -0.075      0.940        -0.160     0.148
# Q_1           -0.0045      0.004     -1.270      0.209        -0.011     0.003
# Q_2            0.0071      0.003      2.067      0.043         0.000     0.014
# Q_3            0.0019      0.004      0.545      0.588        -0.005     0.009
# ==============================================================================
# Omnibus:                        1.195   Durbin-Watson:                   2.831
# Prob(Omnibus):                  0.550   Jarque-Bera (JB):                0.556
# Skew:                           0.094   Prob(JB):                        0.757
# Kurtosis:                       3.416   Cond. No.                         69.4
# ==============================================================================

# %%
mod_ss_nd_e = sm.OLS.from_formula('wage_index ~ nondurable + Q_1 + Q_2 + Q_3', df_ss_nd['from_e'])
mod_ss_nd_n = sm.OLS.from_formula('wage_index ~ nondurable + Q_1 + Q_2 + Q_3', df_ss_nd['from_n'])
mod_ss_nd_a = sm.OLS.from_formula('wage_index ~ nondurable + Q_1 + Q_2 + Q_3', df_ss_nd['all_'])

res_ss_nd_e = mod_ss_nd_e.fit()
res_ss_nd_n = mod_ss_nd_n.fit()
res_ss_nd_a = mod_ss_nd_a.fit()

print(res_ss_nd_e.summary())
print(res_ss_nd_n.summary())
print(res_ss_nd_a.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             wage_index   R-squared:                       0.026
# Model:                            OLS   Adj. R-squared:                 -0.040
# Method:                 Least Squares   F-statistic:                    0.3889
# Date:                Tue, 17 Dec 2013   Prob (F-statistic):              0.816
# Time:                        14:31:33   Log-Likelihood:                 176.44
# No. Observations:                  64   AIC:                            -342.9
# Df Residuals:                      59   BIC:                            -332.1
# Df Model:                           4
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -0.0005      0.004     -0.116      0.908        -0.009     0.008
# nondurable     0.1156      0.198      0.584      0.561        -0.280     0.511
# Q_1            0.0037      0.006      0.638      0.526        -0.008     0.015
# Q_2           -0.0021      0.006     -0.358      0.722        -0.014     0.009
# Q_3            0.0008      0.006      0.130      0.897        -0.011     0.012
# ==============================================================================
# Omnibus:                        3.265   Durbin-Watson:                   2.387
# Prob(Omnibus):                  0.195   Jarque-Bera (JB):                2.409
# Skew:                          -0.431   Prob(JB):                        0.300
# Kurtosis:                       3.402   Cond. No.                         109.
# ==============================================================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             wage_index   R-squared:                       0.029
# Model:                            OLS   Adj. R-squared:                 -0.036
# Method:                 Least Squares   F-statistic:                    0.4465
# Date:                Tue, 17 Dec 2013   Prob (F-statistic):              0.775
# Time:                        14:31:33   Log-Likelihood:                 64.515
# No. Observations:                  64   AIC:                            -119.0
# Df Residuals:                      59   BIC:                            -108.2
# Df Model:                           4
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      0.0078      0.024      0.319      0.751        -0.041     0.057
# nondurable     0.9766      1.137      0.859      0.394        -1.298     3.251
# Q_1           -0.0126      0.033     -0.382      0.704        -0.079     0.054
# Q_2           -0.0250      0.033     -0.755      0.453        -0.091     0.041
# Q_3            0.0015      0.034      0.044      0.965        -0.066     0.069
# ==============================================================================
# Omnibus:                        4.739   Durbin-Watson:                   2.956
# Prob(Omnibus):                  0.094   Jarque-Bera (JB):                4.621
# Skew:                           0.318   Prob(JB):                       0.0992
# Kurtosis:                       4.152   Cond. No.                         109.
# ==============================================================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             wage_index   R-squared:                       0.029
# Model:                            OLS   Adj. R-squared:                 -0.037
# Method:                 Least Squares   F-statistic:                    0.4446
# Date:                Tue, 17 Dec 2013   Prob (F-statistic):              0.776
# Time:                        14:31:33   Log-Likelihood:                 175.21
# No. Observations:                  64   AIC:                            -340.4
# Df Residuals:                      59   BIC:                            -329.6
# Df Model:                           4
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      0.0006      0.004      0.136      0.892        -0.008     0.009
# nondurable     0.1267      0.202      0.628      0.532        -0.277     0.530
# Q_1            0.0019      0.006      0.327      0.745        -0.010     0.014
# Q_2           -0.0040      0.006     -0.685      0.496        -0.016     0.008
# Q_3            0.0004      0.006      0.063      0.950        -0.012     0.012
# ==============================================================================
# Omnibus:                        1.191   Durbin-Watson:                   2.407
# Prob(Omnibus):                  0.551   Jarque-Bera (JB):                0.996
# Skew:                          -0.303   Prob(JB):                        0.608
# Kurtosis:                       2.922   Cond. No.                         109.
# ==============================================================================

# %%
print(df[df.industry.isin(durable_codes)].groupby('either_history')['age'].count())
print(df[df.industry.isin(durable_codes)].groupby('either_history')['age'].count().sum())
# Out:
# either_history
# 0                 124311
# 1                   4705
# dtype: int64
# 129016

# %%
print(df[df.industry.isin(nondurable_codes)].groupby('either_history')['age'].count())
print(df[df.industry.isin(nondurable_codes)].groupby('either_history')['age'].count().sum())
# Out:
# either_history
# 0                 63148
# 1                  2465
# dtype: int64
# 65613

# %% [markdown]
# # Demographic Time Series

# %%
g = df.groupby(level='qmonth')
ts = g[['age', 'sex_d', 'race_d', 'expr', 'edu_bin', 'married_d']].mean().iloc[:-1]

# %%
fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6)) = plt.subplots(figsize=(15, 15), nrows=3, ncols=2)
title_fontdict = {'size': 16}

ts['age'].plot(ax=ax1, label='Age')
ax1.set_title('Age (years)', fontdict=title_fontdict)

ts['sex_d'].plot(ax=ax2)
ax2.set_title('Sex (proportion female)', fontdict=title_fontdict)

ts['race_d'].plot(ax=ax3)
ax3.set_title('Race (proprtion nonwhite)', fontdict=title_fontdict)

ts['expr'].plot(ax=ax4)
ax4.set_title('Experience (years)', fontdict=title_fontdict)

ts['edu_bin'].plot(ax=ax5)
ax5.set_title('Education (see appendix)', fontdict=title_fontdict)

ts['married_d'].plot(ax=ax6)
ax6.set_title('Marital Status (proportion married)', fontdict=title_fontdict)

axes = [ax1, ax2, ax3, ax4, ax5, ax6]
for ax in axes:
    ax.set_xlabel('Quarter')
    add_rec_bars(ax)
    plt.setp(ax.get_xticklabels(), fontsize=12)
    plt.setp(ax.get_yticklabels(), fontsize=12)

fig.tight_layout()

plt.savefig('/Users/tom/Economics/inflation_in_recession/dnwr_zlb/writing/cps_rigidity/demographics_ts.pdf', format='pdf')

# %%
demo_list = ['age', 'sex_d', 'race_d', 'expr', 'edu_bin', 'married_d']

demo_wage_ts = {}

for demo in demo_list:
    demo_wage_ts[demo] = df.reset_index().groupby(['qmonth'] + [demo])['r_wage'].mean()

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(figsize=(15, 10), nrows=2, ncols=2)

t = demo_wage_ts['sex_d'].unstack()
t = t.rename(columns={1: 'Female', 0: 'Male'})
t.plot(ax=ax1)

t = demo_wage_ts['race_d'].unstack()
t = t.rename(columns={1: 'Nonwhite', 0: 'White'})
t.plot(ax=ax2)

t = demo_wage_ts['edu_bin'].unstack()
t.plot(ax=ax3)

t = demo_wage_ts['married_d'].unstack()
t = t.rename(columns={1: 'Married', 0: 'Not Married'})
t.plot(ax=ax4)

axes = [ax1, ax2, ax3, ax4]

for ax in axes:
    leg = ax.legend(loc=0)
    leg.set_title('')
    
    ax.set_ylabel('Wage ($/hour)', fontsize=12)
    plt.setp(ax.get_xticklabels(), fontsize=12)
    plt.setp(ax.get_yticklabels(), fontsize=12)
    add_rec_bars(ax)

plt.savefig('/Users/tom/Economics/inflation_in_recession/dnwr_zlb/writing/cps_rigidity/wages_ts.pdf', format='pdf')

# %% [markdown]
# # With a Recession Dummy

# %%
dates = pd.read_csv('/Users/tom/bin/rec_dates.csv')

# %%
dates
# Out:
#           Peak      Trough
# 0   1857-06-01  1858-12-01
# 1   1860-10-01  1861-06-01
# 2   1865-04-01  1867-12-01
# 3   1869-06-01  1870-12-01
# 4   1873-10-01  1879-03-01
# 5   1882-03-01  1885-05-01
# 6   1887-03-01  1888-04-01
# 7   1890-07-01  1891-05-01
# 8   1893-01-01  1894-06-01
# 9   1895-12-01  1897-06-01
# 10  1899-06-01  1900-12-01
# 11  1902-09-01  1904-08-01
# 12  1907-05-01  1908-06-01
# 13  1910-01-01  1912-01-01
# 14  1913-01-01  1914-12-01
# 15  1918-08-01  1919-03-01
# 16  1920-01-01  1921-07-01
# 17  1923-05-01  1924-07-01
# 18  1926-10-01  1927-11-01
# 19  1929-08-01  1933-03-01
# 20  1937-05-01  1938-06-01
# 21  1945-02-01  1945-10-01
# 22  1948-11-01  1949-10-01
# 23  1953-07-01  1954-05-01
# 24  1957-08-01  1958-04-01
# 25  1960-04-01  1961-02-01
# 26  1969-12-01  1970-11-01
# 27  1973-11-01  1975-03-01
# 28  1980-01-01  1980-07-01
# 29  1981-07-01  1982-11-01
# 30  1990-07-01  1991-03-01
# 31  2001-03-01  2001-11-01
# 32  2007-12-01  2009-06-01
#
# [33 rows x 2 columns]
